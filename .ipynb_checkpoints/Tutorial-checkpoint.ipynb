# %%
import torch
from torch_geometric.loader import DataLoader
from copy import deepcopy

# Custom imports
from Type1 import Type1
from Type2 import Type2
from hg_models import HeteroGNN_SAGE
from early_stopping import EarlyStopping

# %%
type2_dataset1 = Type2("tmp", "../data" , "../y_labels", "rdf")
type2_dataset2 = Type2("tmp", "../data" , "../y_labels", "dubbo")
type2_dataset3 = Type2("tmp", "../data" , "../y_labels", "H2")
type2_dataset4 = Type2("tmp", "../data" , "../y_labels", "hadoop")
type2_dataset5 = Type2("tmp", "../data" , "../y_labels", "systemds")
type2_dataset6 = Type2("tmp", "../data" , "../y_labels", "ossbuilds")
# Out:
# /opt/homebrew/lib/python3.11/site-packages/torch_geometric/data/dataset.py:238: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   if osp.exists(f) and torch.load(f) != _repr(self.pre_transform):
# /opt/homebrew/lib/python3.11/site-packages/torch_geometric/data/dataset.py:246: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   if osp.exists(f) and torch.load(f) != _repr(self.pre_filter):
# /Users/marcusvukojevic/Desktop/AI/SECONDO ANNO/Antonio/peter/to_push/Type2.py:41: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   split_dataset = torch.load(file_path)  # Load the processed dataset for this split

# %%
type2_dataset1
# Out:
# Type2(478)

# %%
type2_dataset1[0]
# Out:
# HeteroData(
#   y=[1],
#   code_structure={ x=[8, 73] },
#   literals_and_constants={ x=[24, 73] },
#   declarations={ x=[8, 73] },
#   types_and_references={ x=[5, 73] },
#   control_flow={ x=[1, 73] },
#   expressions_and_operations={ x=[2, 73] },
#   (code_structure, 0, code_structure)={ edge_index=[2, 20] },
#   (code_structure, 0, literals_and_constants)={ edge_index=[2, 7] },
#   (literals_and_constants, 0_rev, code_structure)={ edge_index=[2, 7] },
#   (literals_and_constants, 0, code_structure)={ edge_index=[2, 7] },
#   (code_structure, 0_rev, literals_and_constants)={ edge_index=[2, 7] },
#   (code_structure, 0, declarations)={ edge_index=[2, 3] },
#   (declarations, 0_rev, code_structure)={ edge_index=[2, 3] },
#   (declarations, 0, code_structure)={ edge_index=[2, 3] },
#   (code_structure, 0_rev, declarations)={ edge_index=[2, 3] },
#   (declarations, 0, declarations)={ edge_index=[2, 28] },
#   (declarations, 0, literals_and_constants)={ edge_index=[2, 9] },
#   (literals_and_constants, 0_rev, declarations)={ edge_index=[2, 9] },
#   (literals_and_constants, 0, declarations)={ edge_index=[2, 9] },
#   (declarations, 0_rev, literals_and_constants)={ edge_index=[2, 9] },
#   (declarations, 0, types_and_references)={ edge_index=[2, 4] },
#   (types_and_references, 0_rev, declarations)={ edge_index=[2, 4] },
#   (types_and_references, 0, declarations)={ edge_index=[2, 4] },
#   (declarations, 0_rev, types_and_references)={ edge_index=[2, 4] },
#   (types_and_references, 0, literals_and_constants)={ edge_index=[2, 5] },
#   (literals_and_constants, 0_rev, types_and_references)={ edge_index=[2, 5] },
#   (literals_and_constants, 0, types_and_references)={ edge_index=[2, 5] },
#   (types_and_references, 0_rev, literals_and_constants)={ edge_index=[2, 5] },
#   (code_structure, 0, types_and_references)={ edge_index=[2, 1] },
#   (types_and_references, 0_rev, code_structure)={ edge_index=[2, 1] },
#   (types_and_references, 0, code_structure)={ edge_index=[2, 1] },
#   (code_structure, 0_rev, types_and_references)={ edge_index=[2, 1] },
#   (declarations, 0, control_flow)={ edge_index=[2, 1] },
#   (control_flow, 0_rev, declarations)={ edge_index=[2, 1] },
#   (control_flow, 0, declarations)={ edge_index=[2, 1] },
#   (declarations, 0_rev, control_flow)={ edge_index=[2, 1] },
#   (control_flow, 0, expressions_and_operations)={ edge_index=[2, 1] },
#   (expressions_and_operations, 0_rev, control_flow)={ edge_index=[2, 1] },
#   (expressions_and_operations, 0, control_flow)={ edge_index=[2, 1] },
#   (control_flow, 0_rev, expressions_and_operations)={ edge_index=[2, 1] },
#   (expressions_and_operations, 0, literals_and_constants)={ edge_index=[2, 3] },
#   (literals_and_constants, 0_rev, expressions_and_operations)={ edge_index=[2, 3] },
#   (literals_and_constants, 0, expressions_and_operations)={ edge_index=[2, 3] },
#   (expressions_and_operations, 0_rev, literals_and_constants)={ edge_index=[2, 3] },
#   (expressions_and_operations, 0, expressions_and_operations)={ edge_index=[2, 4] },
#   (code_structure, 1, code_structure)={ edge_index=[2, 8] },
#   (code_structure, 12, code_structure)={ edge_index=[2, 8] },
#   (code_structure, 1, declarations)={ edge_index=[2, 1] },
#   (declarations, 1_rev, code_structure)={ edge_index=[2, 1] },
#   (declarations, 12, code_structure)={ edge_index=[2, 1] },
#   (code_structure, 12_rev, declarations)={ edge_index=[2, 1] },
#   (literals_and_constants, 1, literals_and_constants)={ edge_index=[2, 6] },
#   (literals_and_constants, 12, literals_and_constants)={ edge_index=[2, 6] },
#   (declarations, 1, literals_and_constants)={ edge_index=[2, 1] },
#   (literals_and_constants, 1_rev, declarations)={ edge_index=[2, 1] },
#   (literals_and_constants, 12, declarations)={ edge_index=[2, 1] },
#   (declarations, 12_rev, literals_and_constants)={ edge_index=[2, 1] },
#   (literals_and_constants, 1, declarations)={ edge_index=[2, 2] },
#   (declarations, 1_rev, literals_and_constants)={ edge_index=[2, 2] },
#   (declarations, 12, literals_and_constants)={ edge_index=[2, 2] },
#   (literals_and_constants, 12_rev, declarations)={ edge_index=[2, 2] },
#   (declarations, 1, declarations)={ edge_index=[2, 2] },
#   (declarations, 12, declarations)={ edge_index=[2, 2] },
#   (declarations, 1, types_and_references)={ edge_index=[2, 2] },
#   (types_and_references, 1_rev, declarations)={ edge_index=[2, 2] },
#   (types_and_references, 12, declarations)={ edge_index=[2, 2] },
#   (declarations, 12_rev, types_and_references)={ edge_index=[2, 2] },
#   (types_and_references, 1, declarations)={ edge_index=[2, 1] },
#   (declarations, 1_rev, types_and_references)={ edge_index=[2, 1] },
#   (declarations, 12, types_and_references)={ edge_index=[2, 1] },
#   (types_and_references, 12_rev, declarations)={ edge_index=[2, 1] },
#   (literals_and_constants, 1, code_structure)={ edge_index=[2, 1] },
#   (code_structure, 1_rev, literals_and_constants)={ edge_index=[2, 1] },
#   (code_structure, 12, literals_and_constants)={ edge_index=[2, 1] },
#   (literals_and_constants, 12_rev, code_structure)={ edge_index=[2, 1] },
#   (declarations, 1, code_structure)={ edge_index=[2, 1] },
#   (code_structure, 1_rev, declarations)={ edge_index=[2, 1] },
#   (code_structure, 12, declarations)={ edge_index=[2, 1] },
#   (declarations, 12_rev, code_structure)={ edge_index=[2, 1] },
#   (code_structure, 1, types_and_references)={ edge_index=[2, 1] },
#   (types_and_references, 1_rev, code_structure)={ edge_index=[2, 1] },
#   (types_and_references, 12, code_structure)={ edge_index=[2, 1] },
#   (code_structure, 12_rev, types_and_references)={ edge_index=[2, 1] },
#   (types_and_references, 1, literals_and_constants)={ edge_index=[2, 2] },
#   (literals_and_constants, 1_rev, types_and_references)={ edge_index=[2, 2] },
#   (literals_and_constants, 12, types_and_references)={ edge_index=[2, 2] },
#   (types_and_references, 12_rev, literals_and_constants)={ edge_index=[2, 2] },
#   (declarations, 1, control_flow)={ edge_index=[2, 1] },
#   (control_flow, 1_rev, declarations)={ edge_index=[2, 1] },
#   (control_flow, 12, declarations)={ edge_index=[2, 1] },
#   (declarations, 12_rev, control_flow)={ edge_index=[2, 1] },
#   (literals_and_constants, 1, expressions_and_operations)={ edge_index=[2, 1] },
#   (expressions_and_operations, 1_rev, literals_and_constants)={ edge_index=[2, 1] },
#   (expressions_and_operations, 12, literals_and_constants)={ edge_index=[2, 1] },
#   (literals_and_constants, 12_rev, expressions_and_operations)={ edge_index=[2, 1] },
#   (expressions_and_operations, 1, literals_and_constants)={ edge_index=[2, 1] },
#   (literals_and_constants, 1_rev, expressions_and_operations)={ edge_index=[2, 1] },
#   (literals_and_constants, 12, expressions_and_operations)={ edge_index=[2, 1] },
#   (expressions_and_operations, 12_rev, literals_and_constants)={ edge_index=[2, 1] },
#   (literals_and_constants, 2, literals_and_constants)={ edge_index=[2, 46] },
#   (literals_and_constants, 3, literals_and_constants)={ edge_index=[2, 46] }
# )

# %%
def train(model, data_loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    for data in data_loader:
        data = data.to(device)
        optimizer.zero_grad()
        graph_output = model(data.x_dict, data.edge_index_dict, data.batch_dict)
        target = data.y.view(-1, 1).to(device)
        loss = criterion(graph_output, target)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(data_loader)

@torch.no_grad()
def test(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    preds, reals = [], []
    for data in loader:
        data = data.to(device)
        
        out = model(data.x_dict, data.edge_index_dict, data.batch_dict)
        loss = criterion(out, torch.reshape(data.y, (data.y.shape[0], 1)))
        total_loss += float(loss)

        pred = out.detach().cpu().numpy()[:, 0] if out.dim() > 1 else out.detach().cpu().numpy()
        real = data.y.detach().cpu().numpy()
        preds.extend(pred)
        reals.extend(real)

    return total_loss / len(loader.dataset), 0, preds, reals

# %%
device = "cpu" # cuda
patience = 15
hidden_channels = 32
batch_size = 32
learning_rate = 0.01

# %%
model = HeteroGNN_SAGE(dataset1, hidden_channels=hidden_channels, out_channels=1, num_layers=4, device=device).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
criterion = torch.nn.L1Loss()

# %%
train_loader = DataLoader(dataset1.load_split("train"), batch_size=batch_size, shuffle=True, collate_fn=dataset1.hetero_collate)
val_loader = DataLoader(dataset1.load_split("val"), batch_size=batch_size, shuffle=False, collate_fn=dataset1.hetero_collate)
test_loader = DataLoader(dataset1.load_split("test"), batch_size=batch_size, shuffle=False, collate_fn=dataset1.hetero_collate)

# %%
early_stopping = EarlyStopping(patience=patience)
best_model_state = None
best_val_loss = float('inf')

for epoch in range(1, 3):
    # Train the model
    train_loss = train(model, train_loader, optimizer, criterion, device)

    # Validate the model
    val_loss, _, _, _ = test(model, val_loader, criterion, device)

    # Save the best model based on validation loss
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_state = deepcopy(model.state_dict())
    
    # Print progress every 10 epochs or at the first epoch
    if epoch % 10 == 0 or epoch == 1:
        print(f'Epoch: {epoch:03d}, Train Loss: {train_loss:.3f}, Val Loss: {val_loss:.3f}')

    # Early stopping check based on validation loss
    if early_stopping(val_loss):
        print(f'Early stopping at epoch {epoch}')
        break
# Out:
# Epoch: 001, Train Loss: 411.776, Val Loss: 0.222
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[89], line 7
#       3 best_val_loss = float('inf')
#       5 for epoch in range(1, 3):
#       6     # Train the model
# ----> 7     train_loss = train(model, train_loader, optimizer, criterion, device)
#       9     # Validate the model
#      10     val_loss, _, _, _ = test(model, val_loader, criterion, device)
#
# Cell In[88], line 4, in train(model, data_loader, optimizer, criterion, device)
#       2 model.train()
#       3 total_loss = 0
# ----> 4 for data in data_loader:
#       5     data = data.to(device)
#       6     optimizer.zero_grad()
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/utils/data/dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/utils/data/dataloader.py:673, in _SingleProcessDataLoaderIter._next_data(self)
#     671 def _next_data(self):
#     672     index = self._next_index()  # may raise StopIteration
# --> 673     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     674     if self._pin_memory:
#     675         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/utils/data/_utils/fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# File /opt/homebrew/lib/python3.11/site-packages/torch_geometric/loader/dataloader.py:27, in Collater.__call__(self, batch)
#      25 elem = batch[0]
#      26 if isinstance(elem, BaseData):
# ---> 27     return Batch.from_data_list(
#      28         batch,
#      29         follow_batch=self.follow_batch,
#      30         exclude_keys=self.exclude_keys,
#      31     )
#      32 elif isinstance(elem, torch.Tensor):
#      33     return default_collate(batch)
#
# File /opt/homebrew/lib/python3.11/site-packages/torch_geometric/data/batch.py:97, in Batch.from_data_list(cls, data_list, follow_batch, exclude_keys)
#      82 @classmethod
#      83 def from_data_list(
#      84     cls,
#    (...)
#      87     exclude_keys: Optional[List[str]] = None,
#      88 ) -> Self:
#      89     r"""Constructs a :class:`~torch_geometric.data.Batch` object from a
#      90     list of :class:`~torch_geometric.data.Data` or
#      91     :class:`~torch_geometric.data.HeteroData` objects.
#    (...)
#      95     Will exclude any keys given in :obj:`exclude_keys`.
#      96     """
# ---> 97     batch, slice_dict, inc_dict = collate(
#      98         cls,
#      99         data_list=data_list,
#     100         increment=True,
#     101         add_batch=not isinstance(data_list[0], Batch),
#     102         follow_batch=follow_batch,
#     103         exclude_keys=exclude_keys,
#     104     )
#     106     batch._num_graphs = len(data_list)  # type: ignore
#     107     batch._slice_dict = slice_dict  # type: ignore
#
# File /opt/homebrew/lib/python3.11/site-packages/torch_geometric/data/collate.py:95, in collate(cls, data_list, increment, add_batch, follow_batch, exclude_keys)
#      92 if attr in exclude_keys:  # Do not include top-level attribute.
#      93     continue
# ---> 95 values = [store[attr] for store in stores]
#      97 # The `num_nodes` attribute needs special treatment, as we need to
#      98 # sum their values up instead of merging them to a list:
#      99 if attr == 'num_nodes':
#
# File /opt/homebrew/lib/python3.11/site-packages/torch_geometric/data/collate.py:95, in <listcomp>(.0)
#      92 if attr in exclude_keys:  # Do not include top-level attribute.
#      93     continue
# ---> 95 values = [store[attr] for store in stores]
#      97 # The `num_nodes` attribute needs special treatment, as we need to
#      98 # sum their values up instead of merging them to a list:
#      99 if attr == 'num_nodes':
#
# KeyboardInterrupt:

# %%
# Reload the best model after training
model.load_state_dict(best_model_state)

# After training completes, evaluate the model on the test set
test_loss, _, predt, realt = test(model, test_loader, criterion, device, model_class)
val_loss, _, predt, realt = test(model, val_loader, criterion, device, model_class) # controllare 
#mse_test = mean_squared_error(predt, realt)

# Append the test metrics
all_metrics['test_loss'].append(test_loss)
all_metrics['val_loss'].append(val_loss)

# Print final test results
print(f'Final Test Loss: {test_loss:.3f}, Final val Loss: {val_loss:.3f}')

# %%
type1_dataset1 = Type1("tmp", "../data" , "../y_labels", "rdf")
type1_dataset2 = Type1("tmp", "../data" , "../y_labels", "dubbo")
type1_dataset3 = Type1("tmp", "../data" , "../y_labels", "H2")
type1_dataset4 = Type1("tmp", "../data" , "../y_labels", "hadoop")
type1_dataset5 = Type1("tmp", "../data" , "../y_labels", "systemds")
type1_dataset6 = Type1("tmp", "../data" , "../y_labels", "ossbuilds")
# Out:
# /opt/homebrew/lib/python3.11/site-packages/torch_geometric/data/dataset.py:238: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   if osp.exists(f) and torch.load(f) != _repr(self.pre_transform):
# /opt/homebrew/lib/python3.11/site-packages/torch_geometric/data/dataset.py:246: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   if osp.exists(f) and torch.load(f) != _repr(self.pre_filter):
# /Users/marcusvukojevic/Desktop/AI/SECONDO ANNO/Antonio/peter/to_push/Type1.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   split_dataset = torch.load(file_path)  # Load the processed dataset for each split
